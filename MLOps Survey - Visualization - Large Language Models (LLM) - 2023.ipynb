# %% [markdown]
# <a href="https://colab.research.google.com/github/fmind/mlops-survey-chatgpt-2023/blob/main/MLOps%20Survey%20-%20Visualization%20-%20Large%20Language%20Models%20(LLM)%20-%202023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FIELDS

# %%
REVIEWS = ''',What is your position/title at your company?,title,position,other,How big is your organization? (number of employees),Are you using LLM at in your organization?,What is your use case/use cases?,fields,tasks,Have you integrated or built any internal tools to support LLMs in your org? If so what?,integrated,solutions,purposes,What are some of the main challenges you have encountered thus far when building with LLMs,challenges,What are your main concerns with using LLMs in production?,concerns,how are you using LLMs?,What tools are you using with LLMs?,tools,What areas are you most interested in learning more about?,topics,How do you deal with reliability of output?,approaches,Any stories you have that are worth sharing about working with LLMs?,stories,Any questions you have for the community about LLM in production?,questions,What is the main reason for not using LLMs in your org?,reasons,What are some key questions you face when it comes to using LLM in prod?,challenges,have you tried LLMs for different use cases in your org?,tried,cases,"If yes, why did it not work out?",problems
0,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
1,Data scientist,Data Scientist,,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Production takes investment,Production Cost,Cost to maintain the service,Cost of Maintenance,Yes,Yes,,Date quality,Data Quality
2,ML Engineer,Machine Learning Engineer,,,50-500,Yes,Text summarisation,,Text Summarization,No,No,,,"Current infrastructure not designed for such massive models, having to implement workarounds for quick fixes","Infrastructure,Workarounds",Cost,Cost,"Open source model (GPT-J, etc)",Seldon,Seldon,Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
3,Founder,Founder,,,1-10,Yes,Data annotation; summarization; search,,"Data Annotation, Text Summarization, Search","https://chat.mantisnlp.com, internal annotation tools",No,MantisNLP,Internal Solution,"out of date info, hallucinations, cost, difficulty in deploying on own infrastructure","Accuracy,Outdated Information,Cost,Deployment",they could serve nonsense or out of date information,"Accuracy, Outdated Information",Open AI API,,,Working with OSS LLMs,Open Source,we provide links to the context from which answers have been drawn.,References,,,,,,,,,,,,,
4,Owner,Owner,,,1-10,Yes,Content production and brainstorming,,"Content Creation, Brainstorming",Not yet,No,,,not yet,,cost of openai API,Cost,Open AI API,"Looking at Pinecone, weaviate, langchain, hugging face","Pinecone, Weaviate, LangChain, Hugging Face",Embeddings,Embeddings,temperature = 0,Temperature Control,,,,,,,,,,,,,
5,Senior Principal Scientist,Principal Scientist,Senior,,"1,000+",Yes,Healthcare,Healthcare,,"yes, confidential",Yes,Confidential,,reliability,Reliability,cost of openai API,Cost,In house model,,,Working with OSS LLMs,Open Source,,,,,,,,,,,,,,,
6,Head of Machine Learning,,Head,Machine Learning,50-500,No,,,,,,,,,,,,,,,,,,,,,,,It's only just now becoming feasible with the ChatGPT API. Before it was too expensive and quality was not good enough.,"Cost, Quality",How to make them reliable.,Reliability,"We are still exploring, eg for support in diagnosis of plant diseases.",Yes,Plant Diseases,So far it's not reliable enough and we don't have spent enough time preparing special content for it. Like rules it should use during diagnosis. The data ChatGPT was trained on seems a bit hit and miss for us.,Reliability
7,Senior Machine Learning Engineer,Machine Learning Engineer,Senior,,"1,000+",Yes,"Search, classification, NER",,"Search, Text Classification, Named Entity Recognition",Just a bunch of shitty scripts I need to refactor in the future.,Yes,,,"Size in all regards. Also training time, response time and that multi gpu debugging is weird.","Size,Training,Response Time,Debugging","Whether the cost involved for us justifies the gains we get, considering we mainly make money from ads and not a really good product.","Cost, Business Value",Other model provider API,"Hugginface, sagemaker, openapi api, tensorflow.","Hugging Face, SageMaker, OpenAPI, TensorFlow",Working with OSS LLMs,Open Source,"Ill refer to the picture of the xkcd guy ""just stir the model until the numbers look right"".",Manual Tuning,"I am not sure what ranks as a LLM. Anything bert and beyond? Anyway, we once used setfit for a production task but found that performance was really tricky to debug. The proof of concept was fine. Production was a complete mess. To this day I dont know why- underlying hardware?",Production issues with LLMs,I mainly wonder how everyone is monitoring these. ALSO. For my company GDPR is a big deal. My DPO shoots down our ideas more often than not or limits it to using the last three months of data. How do other people deal with this?,How do other people monitor LLMs and deal with GDPR limitations?,,,,,,,,,
8,Head of Product,,Head,Product,10-50,No,,,,,,,,,,,,,,,,,,,,,,,No applications,Lack of Use Case,ROI of more expensive models,ROI,Yes,Yes,,No ROI,ROI
9,,,,,50-500,Yes,,,,oi,No,,,lik,,il,,Open AI API,loi,,Working with OSS LLMs,Open Source,lo,,lo,,lo,,,,,,,,,,
10,Senior Data Engineer,Data Engineer,Senior,,50-500,Yes,"text embeddings for search, text generation to help the business people do their job","Business, Search","Text Embeddings, Text Generation","Yes, we're using OpenAI for a couple of internal tools.",Yes,OpenAI,Internal tools,,,Cost. But our issues with productionisation is more general than just for LLMs,"Cost, Productionization",Open AI API,streamlit,Streamlit,Inferenece for LLMs,Inference,"All internal tools, reliability is not a major concern for now",Nothing,,,,,,,,,,,,,
11,Machine learning engineer,Machine Learning Engineer,,,"1,000+",Yes,"Natural Language interface, domain specific content creation",,"Natural Language Interface, Content Creation",,,,,Prompt debugging! We need a new form of debugger.,Debugging,They are erratic,Reliability,Open AI API,,,Working with OSS LLMs,Open Source,We have control systems,Control Systems,,,,,,,,,,,,,
12,Senior Data Scientist,Data Scientist,Senior,,"1,000+",Yes,Chatbots and Text classification,Customer Service,"Chatbots, Text Classification",One of our use cases is to build text classification models for each of our customers (we are a B2B company). Achieved this using LLMs and some engineering,Yes,,Text Classification,,,,,"Open source model (GPT-J, etc)",,,Embeddings,Embeddings,,,,,,,,,,,,,,,
13,ML Engineer,Machine Learning Engineer,,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
14,Snr MLOps Engineer,MLOps Engineer,Senior,,50-500,Yes,Adapters,,Adapters,"Yes, training setup as well as inference setup",Yes,,,Latency and deployment time,"Latency,Deployment",Resources usage along with latency and deployment time,"Resource Usage, Latency, Deployment","Open source model (GPT-J, etc)",,,Inferenece for LLMs,Inference,Assessment at evaluation,Model Evaluation,,,,,,,,,,,,,
15,,,,,"1,000+",Yes,,,,,,,,,,,,,,,Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
16,Senior ML engineer,Machine Learning Engineer,Senior,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,"Two main reasons: 1. Very compute & power hungry 2. Cannot be relied upon as it will very confidently return incorrect information or in “existent facts” which is problematic for use in my industry.

Eg it took us less than 3mn to get BioGPT to tell us vaccines cause autism","Compute, Reliability","What uses cases does it have for our business? how much gain do we get from using an LLM vs a simpler language model where we can control fact and outputs? How much will it cost (to deploy, and run)","Business Use Cases, Cost",We abandoned the idea pretty quickly,Yes,,We got terrible suggestions from the LLM that were false information and would be detrimental to the business,"Veracity, Business Risks"
17,Machine Learning Engineer,Machine Learning Engineer,,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,"We use medium-sized language models (e.g. RoBERTa-base) as the backbone for our deployed NLP models because they can perform inference on CPU, which is cheap. We don't use LLMs (e.g. ChatGPT, GPT-3) because the APIs are expensive, and fine-tuning them to perform NLP tasks other than language generation (e.g. NER, open-set intent classification) is not straightforward.","Cost, API Limitations, Fine-tuning Difficulty",How can we ensure the same version of the model is being used? How can we supply a random seed to get deterministic results? How can we minimize LLM API usage costs? How can we fine-tune a LLM on a niche task without having to replicate the weights of the LLM? How can we deploy our own copy of an open-source LLM without breaking the bank?,"Version Control, Random Seed, API Usage Costs, Fine-tuning, Deployment Cost",Yes,Yes,,"We evaluated a LLM (GPT-3) against RoBERTa fine-tuned on our small task-specific dataset, and our fine-tuned model got much higher accuracy than GPT-3 did.","Cost, Efficiency"
18,,,,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Not much usecases for us,Lack of Use Case,,,,,,,
19,Founding Data Scientist,Data Scientist,Founding,,1-10,Yes,"Summarization, topic extraction, root-cause analysis",,"Text Summarization, Topic Extraction, Root-Cause Analysis","Not much, just some prompt storage and an automated retries to deal with different failure cases.",No,,,"Hallucinations are a big one. In general, problems are hard to debug without careful manual review, so we're only using them when the amount of results generated is small enough to review by hand.","Debugging,Hallucinations","Reliability, cost, injecting domain-specific language and understanding into them","Reliability, Cost, Domain-specific Language",Open AI API,,,Embeddings,Embeddings,"Automated retries for some simple & obvious failures, manual review for everything else","Automated Retries, Manual Review",,,Where are others drawing the line between training models locally and using LLMs? Have others had success with using LLMs to bootstrap training data for smaller local models?,Where is the line drawn between training models locally and using LLMs? Can LLMs be used to bootstrap training data for smaller models?,,Boostrap Training,,,,,,,
20,CTO,CTO,,,1-10,Yes,Marketing,Marketing,,Not yet,No,,,Still developing,,Cost,Cost,Open AI API,,,Fine tunning LLMS,Fine-Tuning,,,,,,,,,,,,,,,
21,Machine Learning Engineer,Machine Learning Engineer,,,"500-1,000",No,,,,,,,,,,,,,,,,,,,,,,,Not applicable to the domain,Not Applicable,Not yet,,,,,,
22,Head of AI,,Head,AI,"1,000+",Yes,Scanning large text corpora using an LLM and some cases with text summary for now,,"Text Scanning, Text Summarization",Not (yet).,No,,,It’s a mix of taming a beast and using alchemy,,Consistency of the output quality,Consistency,Other model provider API,./.,,Working with OSS LLMs,Open Source,HITL,Human-in-the-Loop (HITL),They take every Input equally serious which makes for some great laughs…,LLMs provide entertainment value,,,,,,,,,,,
23,Product,,,Product,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Production LLM lifecycle and use cases not clear,"Production Lifecycle, Lack of Use Case",Data governance,Data Governance,no,No,,,
24,Lead Data Scientist,Data Scientist,Lead,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,Cost / right use-case,"Cost, Lack of Use Case",,,,,,,
25,Co-founder,Co-Founder,,,1-10,Yes,AI for e-commerce,E-commerce,,No,No,,,Hardware requirements and AI accelerators compatibility,"Hardware,Compatibility",Inference scalability,Scalability,"Open source model (GPT-J, etc)","PyTorch, AWS SageMaker, OpenAI's API, Midjourney, CLIP/BLIP/etc models","PyTorch, SageMaker, OpenAI, Midjourney, CLIP, BLIP",Inferenece for LLMs,Inference,,,,,"Any opinions regarding the newer AI accelerator chips? Many people fighting for GPUs, but not necessarily mentioning AWS Inferentia 2 chips, TPUs, Habana Gaudi, etc.","What are opinions on newer AI accelerator chips like AWS Inferentia 2 chips, TPUs, Habana Gaudi, etc.?",,,,,,,,,
26,MLE,Machine Learning Engineer,,MLE,50-500,Yes,,,,dbt pre-processing to get the text right for the prompts and test it,No,DBT,Prompt testing,"explainability, expense, embeddings","Explainability,Expense,Embeddings",see above,,Open AI API,metaflow,Metaflow,Embeddings,Embeddings,,,,,,,,,,,,,,,
27,Snr MLE,Machine Learning Engineer,Senior,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,Exploration stage,Exploration Stage,Putting company data in the right structure and updating the model with it,Data Preparation,yes,Yes,,getting fine tune right and LLMops pipeline,"Fine Tuning, LLMOps"
28,Director of Artificial Intelligence,,Director,Artificial Intelligence,"1,000+",Yes,"Novelty - ChatGPT is being explored to optimize code, critique written works, etc.",,"Code Optimization, Written Work Critique",No,No,,,,,Complacency and atrophy of critical thinking,Critical Thinking,"Open source model (GPT-J, etc)",Microsoft Azure OpenAI services,"Microsoft Azure, OpenAI",Fine tunning LLMS,Fine-Tuning,Educate others on the limitations and proper use.,Education,"One of our citizen data scientists now (figuratively) ""worships"" ChatGPT Gods given its capabilities. LOL.",Citizen data scientist impressed with ChatGPT capabilities,None at the moment given our priorities are mostly with computer vision and time-series data analysis.,,,,,,,,,,
29,Data Scientist,Data Scientist,,,50-500,Yes,"Summarisation, Email generation, Information retrieval",,"Text Summarization, Email Generation, Information Retrieval",Modular python library for interacting with multiple LLM providers/APIs and a standardized prompt generation framework.,No,"Python, API",Prompt Generation,Consistency of formatting in freeform LLM text generation. Subtleties in prompt engineering.,,"Detecting truthfulness, hallucination. Output validation. Risk of monopolisation and centralised access to LLM as a service","Truthfulness, Hallucinations, Validation, Monopolization",Other model provider API,Python,Python,Working with OSS LLMs,Open Source,,,,,,,,,,,,,,,
30,Co-founder and CTO,"Co-Founder, CTO",,,1-10,Yes,Prompt autogeneration and synthetic data generation,,"Prompt Autogeneration, Synthetic Data Generation",,,,,Reproducibility,"Formatting,Prompt Engineering",Hallucination and latency,"Hallucination, Latency",Open AI API,HoneyHive,HoneyHive,Fine tunning LLMS,Fine-Tuning,"Multi-responses shown to user side by side, ghost writer style dropout","Multi-Responses, Ghost Writing",,,How are you thinking about tracking user feedback in production?,How to track user feedback in production?,,,,,,,,,
31,,,,,50-500,Yes,,,,,,,,,Reproducibility,,,,,,Working with OSS LLMs,Open Source,,,,,,,,,,,,,,,
32,Senior Software Enginner,Software Engineer,Senior,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,No business need yet,Lack of Use Case,,,,,,,
33,Co-founder,Co-Founder,,,1-10,No,,,,,,,,,,,,,,,,,,,,,,,We're learning,,,,,,,,
34,ML Developer,Machine Learning Developer,,,"500-1,000",Yes,Question Answering,,Question Answering,yes,Yes,,,latency,Latency,"latency, factuality","Latency, Factuality","Open source model (GPT-J, etc)",,,Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
35,,,,,1-10,No,,,,,,,,,,,,,,,,,,,,,,,"Cost, Latency, Accuracy","Cost, Latency, Accuracy","Cost can be high, hallucinations","Cost, Hallucinations",,,,,
36,data scientist,Data Scientist,,,"500-1,000",No,,,,,,,,,,,,,,,,,,,,,,,not really in our domain,Not Applicable,,,no - closest we've got to dealing with language is fuzzy lookups,No,,,
37,Senior Machine Learning Engineer,Machine Learning Engineer,Senior,,10-50,Yes,Question generation for accountants,Accounting,Question Generation,built internal,Yes,,,reducing latency,Latency,not knowing the data used for the initial training,Data Transparency,In house model,"TensorFlow, TFX","TensorFlow, TFX",Inferenece for LLMs,Inference,yes,,,,,,,,,,,,,,
38,Founder,Founder,,,1-10,Yes,Zero-shot/Few Shot classification for data enrichment,,"Zero-shot/Few Shot Classification, Data Enrichment","Internally, we use BERT to create embeddings, then train a smaller model on customer data.",Yes,BERT,Embeddings,Infrastructure costs.,Cost,"Is what I;m building getting obsolete in 3 months,",Obsolescence,In house model,In house Bert (from Huggingface) + Open AI,"In House, Bert, HuggingFace, OpenAI",Fine tunning LLMS,Fine-Tuning,I am stuck with this right now - can I integrate these into the UI for AI Hero.,UI Integration,ChatGPT API output is different every time for the same input - makes it hard to create a reliable service.,Reliability with ChatGPT API is hard,How are you managing training/deployment of these?,How to manage training/deployment of LLMs?,,,,,,,,,
39,SRE,Site Reliability Engineer,,,"1,000+",Yes,analyze logs,,Log Analysis,no,No,,,Analyzing results,Result Analysis,security,Security,In house model,in house built tool,In House,Fine tunning LLMS,Fine-Tuning,Very manual so far.,Manual Review,confidential,Confidentiality,no,,,,,,,,,,
40,"Cofounder (normally product manager, but also wearer of many hats)",Co-Founder,,Product Manager,1-10,No,,,,,,,,,,,,,,,,,,,,,,,"1. gcm diagflow is good for complete basic dialogs, 2. halucinations 3.a. how to make answers be focused on what my company is doing rather than general answers, 3.b. how to keep that evolving as we learn more about the customers 3.c. how to prevent a practical joker who's conversing with my llm to inject some practical joke into it 4. if im relying on openai-s llm, i need to always get a reply what happens if they're busy, whats the proverbial 'failover'","Simpler Tools, Hallucinations, Fine-Tuning, Model Regeneration, Security, Fail-over",how to get it to use my company's specific knowledge,Domain Specific Knowledge,not thoroughly enough yet,No,,still working on it,
41,Data Architect,Data Architect,,,"1,000+",Yes,Search and chat on proprietary data,,"Search, Chatbot",No,No,,,"Automation amd scaling of transfer learning, tuning and reinforcement learning","Automation,Scaling,Transfer Learning,Tuning,Reinforcement Learning",Scaling,Scalability,Open AI API,"Lang chain, k8s, gcp","LangChain, Kubernetes, GCP",Learning from new/private data,Fine-Tuning,Not a concern. In-house,Nothing,No,,"Best automated/scalable pipeline for tuning,, transfer learning (augmentation), reinforcement feedback","What is the best pipeline architecture for LLM tuning, transfer learning, and reinforcement feedback?",,,,,,,,,
42,Senior software engineer,Software Engineer,Senior,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,No need atm,Lack of Use Case,Reliability,Reliability,,,,,
43,consultant,Consultant,,,1-10,No,,,,,,,,,,,,,,,,,,,,,,,we'll be using at a startup I'm part of,,cost and fit for purpose. Actual market validation,"Cost, Market Validation",yes. I've used them for classification,Yes,Classification,they are in prod for that use case,
44,CTO,CTO,,,50-500,Yes,"Product (Software) recommendations, Internal Q&A, Marketing content, and Customer support","E-commerce, Customer Support, Marketing","Recommendation, Question Answering, Text Generation","Langchain, OpenAI Playground, ChatGPT, PromptLayer, Weaviate",No,"Langchain, OpenAI Playground, ChatGPT, PromptLayer, Weaviate",,Rapidly changing APIs,API changes,Hallucinations misleading customers,"Hallucinations,Misleading customers",Open AI API,PromptLayer,PromptLayer,Embeddings,Embeddings,"Pre/post-processing, constitutional / self-auditing, customer feedback thumbs up/down, custom embedding matrix","Pre/Post-Processing, Self-Auditing, Customer Feedback, Custom Embedding Matrix",,,How might you avoid siloing all of your embeddings when different teams need different tools without building it all in house yet all would benefit from the combined collection?,How to avoid siloing embeddings when different teams need different tools without building it all in house?,,,,,,,,,
45,Data scientist / co-founder,"Data Scientist, Co-Founder",,,1-10,Yes,Information retrieval and text generation.,,"Information Retrieval, Text Generation","We have some output validation methods and templates, basically regex matching prompts.",Yes,,Output validation,Input length limitation and having to work around it with non-optimal methods.,Input length limitation,Hallucinations,Hallucinations,Open AI API,"Langchain, Huggingface, Polars","LangChain, HuggingFace, Polars",Fine tunning LLMS,Fine-Tuning,We implement checking with less stochastic tools.,Stochastic Tools Checking,Content language matters a lot!,Content language is important for LLMs,,,,,,,,,,,
46,Analytics engineer,Analytics Engineer,,,50-500,Yes,Chatbot,,Chatbot,In POC at the moment,Yes,,POC,Vectorizing CRUD and ci / CD,"CI/CD,Performance",To get better at semantic search,Semantic search,Open AI API,"Langchain, pinecone, slack and aws","LangChain, Pinecone, Slack, AWS",Embeddings,Embeddings,,,,,"How to better deploy python apps using aws and operationalizing it.
How to better manage vector indexes.",How to deploy and operationalize python apps using AWS?,,,,,,,,,
47,"Director, Innovation",,Director,Innovation,50-500,No,,,,,,,,,,,,,,,,,,,,,,,Data privacy concerns,Data Privacy,Difficulty or ease of maintenance; costs; data privacy,"Maintenance, Costs, Data Privacy",Not yet,No,,na,None
48,ML & MLOps practice lead,,Lead,ML & MLOps,50-500,Yes,"Text classification, text generation",,"Text Classification, Text Generation",,,,,"Compute performance, fine tuning challenges, explainability","Performance,Explainability,Fine-tuning",,,"Open source model (GPT-J, etc)",,,Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
49,Founder,Founder,,,1-10,Yes,Social media idea generation,Social Media,Text Generation,No just used langchain and OpenAI,No,"Langchain, OpenAI",,Prompt engineering; handling very large documents,"Prompt engineering,Handling large documents",Bad data/completions; runtime errors parsing completions (we use regex to parse each line ),"Bad data,Runtime errors",Open AI API,LangChain,LangChain,Fine tunning LLMS,Fine-Tuning,We don’t do anything right now,Nothing,,,,,,,,,,,,,
50,CTO,CTO,,,1-10,Yes,Semantic data extraction and corporate governance,Corporate Governance,Semantic Data Extraction,"I'm unable to utilise LLM's currently due to data security restrictions, however as a OpenAI beta tester, around 2 years ago I created a business Operational Delivery Framework for a £500M nuclear project. I then transferred the learning framework to £5B project.",No,,Operational Delivery Framework,Environment dependency conflicts,Environment dependency conflicts,Safe and ethical usage,"Safety,Ethics",Open AI API,Use case dependent,,Fine tunning LLMS,Fine-Tuning,"AI is replaced by HI(Human) for final check, always.",Human-in-the-Loop (HITL),"Yes, the ODF I created was regarded as best in class by regulators and has been suggested to be implemented as new gold standard. I used GPT3 to advise on the design of the framework, and to write all the necessary code to create it.",GPT3 used to create best in class ODF framework,"Nope, no questions, just a great big thankyou, and a virtual high five for all the awesome peeps 🙏",,,,,,,,,,
51,MLOps Engineer,MLOps Engineer,,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,Still evaluating infrastructure requirements and ways to make it traceable if things go wrong,,"Retraining, tackle hallucinations and avoid wrong results","Retraining, Hallucinations, Accuracy",No,No,,,
52,Junior developer,Developer,Junior,,1-10,Yes,Creating a chat bot to query data efficiently for managers,,"Chatbot, Information Retrieval",Not yet but its in production. Using langchain.,Yes,Langchain,Production,"The main challenges are using the different tools from langchain to optimise for the use case. There are a lot of things to consider. Also, we use ts and angular front end so not having all the tools that are available in python required us to have python as the backend now.","Optimization,Interoperability",It’s how useful/valuable it will actually be for the client.,Customer Value,Open AI API,Langchain/ts/csharpe/angular.,"LangChain, TypeScript, C#, Angular",Fine tunning LLMS,Fine-Tuning,We havent gotten to that yet.,Nothing,"They are amazing. But as mentioned, a chatbot alone is probably not enough to be useful, hence building out other capabilities will become important.",Integrations are important for chatbot,,,,"Infrastructure Requirement, Traceability",,,,,,,
53,deep learning engineer,Deep Learning Engineer,,,"1,000+",Yes,extract information from image and text of medical domain,Medical,"Information Extraction, Image Analysis, Text Analysis",no,No,,,deploy models into production,Deployment,hight training & inference cost,"Training cost,Inference cost","Open source model (GPT-J, etc)","transformers, triton inference server","Transformers, Triton Inference Server",Working with OSS LLMs,Open Source,,,,,,,,,,,,,,,
54,Co-Founder,Co-Founder,,,10-50,No,,,,,,,,,,,,,,,,,,,,,,,Lack of use cases that require so much sophistication,Lack of Use Case,"cost of maintenance, lack of institutional knowledge","Cost of Maintenance, Institutional Knowledge",No,No,,,
55,Intern,,Intern,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Because I am in education sector.,Not Applicable,when you use LLM in production it can fail any time,Reliability,NO,No,,,
56,CTO,CTO,,,1-10,Yes,Coding,,Coding,VSCode Extension,Yes,,VSCode Extension,Work with 3 AI providers at the same time,Interoperability,The wrong respond from the model,Incorrectness,Open AI API,Code GPT https://codegpt.co,Code GPT,Embeddings,Embeddings,Now it is just responds tickets in github,GitHub Tickets,"The extension hace more than 200,000 downloads and it work great!",LLM leads to great success,,,,,,,,,,,
57,Software Development Engineer,Software Development Engineer,,,"1,000+",Yes,"(Not in my org, at work I don’t do this, it’s personal) Cover letter generator based on resume and job description",,Text Generation,,,,,Embedding with appropriate data effectively,Embedding,Being dependent on one company for the API so far. Having models of equivalent performance whose weights were public would be a great relief,Vendor Lock-in,Open AI API,"Gpt index, langchain","GPT Index, LangChain",Embeddings,Embeddings,"Prompt engineering, allow user to be specific, and of course re-generate","Prompt Engineering, User Feedback, Regeneration",,,,,,,,,,,,,
58,Data Science Team Lead,Data Science Team Lead,,,10-50,Yes,Topic sentiment evaluation on text,,"Sentiment Analysis, Topic Modeling",,,,,Managing training data labeling,Data labeling,explainability,Explainability,"Open source model (GPT-J, etc)",AWS Sagemaker,AWS Sagemaker,Fine tunning LLMS,Fine-Tuning,Test each new model candidate on test set,Model Evaluation,,,,,,,,,,,,,
59,Sr. ML Eng,Machine Learning Engineer,Senior,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,inference cost vs. impact on revenue,Return of Investment,how to reduce inference cost,Cost,,,,,
60,Senior AI Expert,AI Expert,Senior,,50-500,Yes,Medical Diagnostics Support,Medical,Diagnostics Support,"No, we rely on open source tools",No,,,"Explainability, Testing, Getting ground truth data","Explainability,Testing,Data labeling",Trustworthiness,Trustworthiness,"Open source model (GPT-J, etc)","Milvus DB, FastAPI, Hugginface, Pytorch, etc.","Milvus DB, FastAPI, Hugging Face, PyTorch",Working with OSS LLMs,Open Source,We try to make the output as transparent as we can (using explainability techniques) and not relying upon LLM for the end decision (these are used as a support tool),"Model Explainability, Human Decision Making",,,,,,,,,,,,,
61,Data Science Engineer,Data Science Engineer,,,50-500,Yes,Assistant chat bot,,Chatbot,"Langchain. Will serve the bot from a flask server, being set up for the bot, into our existing java platform",Yes,Langchain,Chatbot,"Langchain LLM Parse error. Turbo not using multiple tools for some reason, when davinci-003 did",Parse error,"Need HIPAA compliance, so trying to get on Azure. Worried about the contract falling through","HIPAA Compliance,Contracts",Open AI API,Langchain. All my agent’s tools are custom-built. I hit our internal APIs with them,LangChain,I want deep knowledge on how to make the ReAct pattern work in various edge cases,"React Pattern, Edge Cases","Will have friendly internal users using it first in the course of serving customers, and giving us per-message feedback",User Feedback,davinci-003 hallucinating using an existing tool without actually using it!,LLM hallucination without actual usage,How should I split my initial prompt up between turbo’s System prompt and the first Human prompt I give it?,How to split initial prompt between turbo's System prompt and the first Human prompt?,,,,,,,,,
62,Head of Data and ML,,Head,Data and ML,10-50,No,,,,,,,,,,,,,,,,,,,,,,,"No Use case, being a fintech startup, besides helping with processing documents",Lack of Use Case,why waste the money,Cost,no,No,,,
63,ML/MLOps Engineer,ML/MLOps Engineer,,,"500-1,000",No,,,,,,,,,,,,,,,,,,,,,,,No clear use case,Lack of Use Case,"Running them, fine tuning, cost","Running, Fine-tuning, Cost",Nope,No,,,
64,"Data Scientist, HappyFresh",Data Scientist,,,"500-1,000",No,,,,,,,,,,,,,,,,,,,,,,,Not,,,,,,,,
65,Data Scientist,Data Scientist,,,10-50,Yes,Automation of report writing.,,Report Generation,"Yes.
Responsible for the design, building, testing and deployment of a GPT-3.5 application that processes numerical data and free-response text in tabular form to generates commentary and analysis for a visual report. Researchers are only required to upload a zip folder(1-click).
Technologies: AWS lambda, Docker (ECR/ECS), GPT3.5, PyTorch.",Yes,,,"control of the output for our usecase. Reports need to understand the client's intent and take information from briefing calls and key erquriements. These can help guide the output, but now always.",Output control,Thta it will hallucinate something that we won;t pick up in the report editing phase,Hallucinations,Open AI API,Torch and Pandas,"Torch, Pandas",Prompt Engineering (Riley Goodside),Prompt Engineering,Have editors comb through it,Manual Review,We aim to turn a report around from survey finishing to client inbox in 24 hour. So far we are at 48 hours.,Development time is under-estimated,,,,,,,,,,,
66,Data Scientist,Data Scientist,,,50-500,Yes,"LLM in Marketing, Custom data","Marketing, Custom Data",Text Generation,HF Inference Endpoints,Yes,HuggingFace,"Chatbot, Question Answering",Cloud Cost,Cost,No proper documentation,Documentation,Other model provider API,,,Fine tunning LLMS,Fine-Tuning,,,,,,,,,,,,,,,
67,Senior Data Scientist,Data Scientist,Senior,,"500-1,000",No,,,,,,,,,,,,,,,,,,,,,,,"We don't have a need for generating unstructured data, we work in small languages, our text is very domain specific, LLMs are very compute intensive -> expensive to run and take a lot of work to set up.","Domain Specific Language, Compute Intensive, Cost","Cost, latency, actual performance in the languages / domains we work with (real languages, not programming)","Cost, Latency, Accuracy",Nope. Tried some BERT for classification but that hardly counts as an LLM. And I've made models as big as BERT I think.,No,,,
68,Data Scientist,Data Scientist,,,50-500,Yes,chatbot/voice assistant,,"Chatbot, Voice Assistant",just used RASA for chatbot creation and haystack for open domain question answering,Yes,"RASA, Haystack","Chatbot, Question Answering","currently used only pre-trained models, biggest challenge was to obtain data for specific domain fine tuning",Data acquisition,it is very important in my opinion to accurately monitor the kind of usage to prevent frauds or malicious intentions,"Usage monitoring,Fraud prevention",Other model provider API,Haystack,Haystack,Fine tunning LLMS,Fine-Tuning,"it depends from specific context and specific use cases, in my experience I rely on validation set and a validation tool that estimates accuracy of answers based on answers manually scrutinized by humans","Validation Set, Validation Tool, Human Scrutiny",not so far,,it would be interesting a discussion about how to control the output and in general the kind of usage the system has been exposed,How to control the output and usage of LLMs?,,,,,,,,,
69,Head of Data Science,,Head,Data Science,"1,000+",Yes,"Entity matching, customer service responses (souped up/targetted FAQ).",Customer Service,"Entity Matching, Text Classification",yes - high scale server on K8's,Yes,Kubernetes,,K8's caches... TESTING.,Testing,"cost, latency, truthfulnes - but also

Maybe management in the sense of versioning and resolving / attributing issues?

Copyright and intellectual property liability - who knows what it's been trained on and what it might spit out... What happens if it provides a Disney script for an advert? (I know the answer - nothing good).

Safety : what if it tells someone to kill themselves? Or spits out a recipe to make smallpox? (I am being kind of silly here, but... not entirely)","Cost,Latency,Truthfulness,Versioning","Open source model (GPT-J, etc)","not sure what this means - we use k8's and cloud functions to run them, also interface to case management solutions.",Kubernetes,calibration of llm output / calbration and testing of llms,"Calibration, Testing",badly. We do lots of testing but I constantly feel we are on shaky ground.,Extensive Testing,"We had a nice time selecting models, proving it would all work and using TSNE and PCA to reduce the dimensionality of embeddings and get compression for our vector lookup system... Very good and satisfying work, we got prizes and praising from all. Then camesome dreadful times making our vector lookup system work under load for long durations in a proper prod environment (where we couldn't touch it to do things like restart it or reload the index). I think this will be a big issue in the future - we need things that are as reliable as oracle for running the inferences, we do not have them - everything is glued together (I am guessing this is not true if you work for Google...)",Scalability is a real challenge,,,,,,,,,,,
70,Founder,Founder,,,1-10,Yes,We are making tools to monitor and improve the performance of LLMs,,"Performance Monitoring, Model Improvement",No additional tools,No,,,,,Hallucinations,Hallucinations,"Open source model (GPT-J, etc)",UpTrain,UpTrain,Embeddings,Embeddings,We are building a tool for that,Tool Development,,,How is everyone thinking about fine-tuning LLMs for their use-cases?,How to fine-tune LLMs for specific use-cases?,,,,,,,,,
71,CEO,CEO,,,1-10,Yes,"Embeddings, Feature Extraction, Chatbot",,"Embeddings, Feature Extraction, Chatbot",Database connections,No,,,Context length limitations,Context length limitation,"Hallucinations, rate limiting,","Hallucinations, Rate Limitations",Open AI API,"Langchain, Llama Index, Deep lake, Weaviate","LangChain, Llama Index, Deep Lake, Weaviate",Fine tunning LLMS,Fine-Tuning,Error handling,Error Handling,,,,,,,,,,,,,
72,Founder,Founder,,,1-10,Yes,"Text summarization, code generation",,"Text Summarization, Code Generation",No,No,,,Dealing with vector stores,Vector stores,Keeping agent on track with system (OpenAI’s ChatGPT) or role,Consistency,Open AI API,LangChain,LangChain,Embeddings,Embeddings,,,,,What are some of the best practices for dealing with LLMs or foundation models?,What are the best practices for dealing with LLMs or foundation models?,,,,,,,,,
73,Senior Dara scientist,Data Scientist,Senior,,"1,000+",Yes,"Chatbot, semantic search",,"Chatbot, Semantic Search",Deploy open source LLM,Yes,,,"Data privacy, big models","Data privacy,Model size",Fake information,Fake information,"Open source model (GPT-J, etc)",PyTorch huggingaface,"PyTorch, Hugging Face",Inferenece for LLMs,Inference,Generate multiple output,Multiple Output Generation,Not really,,Chatgpt for domain knowledge,How to use Chatgpt for domain knowledge?,,,,,,,,,
74,ML Engineer,Machine Learning Engineer,,,"1,000+",Yes,Customer support,Customer Support,,We’ve integrated with model store!,Yes,,,Memory requirements during inference,"Memory,Inference",Slow start up times/it’s very different from regular code,"Slow start up times,Different from regular code",In house model,Hugging Face,Hugging Face,Inferenece for LLMs,Inference,We’re doing classification not generation,Proxy Task,,,Curious to hear about other use cases!,What are other use cases for LLMs?,,,,,,,,,
75,Director,,Director,,1-10,No,,,,,,,,,,,,,,,,,,,,,,,No need yet,Lack of Use Case,I don't need them,,"Yes, too heavy",Yes,,Too heavy,Model Size
76,Technical Marketing Manager,Technical Manager,,Marketing,10-50,Yes,Content marketing and text drafting,Marketing,Text Generation,not at the moment in my department,No,,,,,costs under control and reliability,"Costs,Reliability","Open source model (GPT-J, etc)",,,Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
77,Head of MLOps,,Head,MLOps,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,"Currently assessing the risk and potential applications, performing POCs.",Business Risks,"What are the potential risks, where are the benefits worth the costs for enterprise grade integration, how do we make these things secure, how do we monitor?","Security, Monitoring, ROI",In the process of doing so.,Yes,,We’re being thorough.,Thoroughness
78,CDO,CDO,,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Wee are exploring the space but don't feel they are ready for production use yeet,Not Production Ready,"How to pin them to a domain, how to verify the veracity of teh outcome and how to best chain them with APIs","Domain Specific Knowledge, Outcome Verification, API Integration",We are exploring customer facing and colleague facing applications,Yes,Customer and Colleague Facing Applications,Concerns about sticking to a domain and about veracity if the answers,"Domain-specificity, Veracity"
79,Owner,Owner,,,1-10,Yes,"sales pipelines, text generation, data classification and many more",Sales,"Text Generation, Data Classification","Yes, several",Yes,,,The need to use Python,Python,"Cost, accuracy","Costs,Accuracy",Open AI API,Zapier,Zapier,Finetuning and embeddings,"Fine-Tuning, Embeddings",extensive testing,Extensive Testing,,,,,,,,,,,,,
80,Agricultue consultant,Consultant,,Agriculture ,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,$,Cost,$,Cost,No,No,,No,None
81,Data scientist,Data Scientist,,,1-10,Yes,,,,Yes,Yes,,,Computing power,Computing Power,,,Open AI API,,,Fine tunning LLMS,Fine-Tuning,,,,,,,,,,,,,,,
82,Product Owner Data Science,Product Owner,,Data Science,50-500,No,,,,,,,,,,,,,,,,,,,,,,,MLOps and DataScience rather young discipline. We are currently working on an LLM use case though,Lack of Maturity,"Runtime, Drift detection","Runtime, Drift Detection",No,No,,,
83,Team Lead DS & MLE,Team Leader,Lead,DS & MLE,50-500,No,,,,,,,,,,,,,,,,,,,,,,,Domain specific challenges for what we do. Digging into how we could train LLM to fit the needs.,"Domain specific challenges,Fine Tuning",What is it? There is just the huge gap in understanding about analyzing text vs generating text.,"Understanding, Analyzing vs Generating Text",We were using s-BERT in our primary recsys model. Recent modeling efforts have reset to simpler systems that are performing better. Still using it in a 2nd model for a clustering challenge.,Yes,"Recommendation System, Clustering",,
84,Co-founder,Co-Founder,,,1-10,Yes,Semantic vector embeddings as a feature into RecSys,Recommender Systems,Semantic Vector Embeddings,Not yet,No,,,"Sparse representations (e.g. tfidf) are easier to work with for our use-cases, because they survive simple aggregation better.",Sparse Representation,Explainability of embeddings.,Explainability,"Open source model (GPT-J, etc)",,,Embeddings,Embeddings,We have come up with a large list of proxy metrics that we found correlate with performance on our tasks - so we track those.,Proxy Metrics,"As far as embeddings are concerned, we haven't found a clear advantage of LLMs vs simpler models (tfidf) trained on a relevant dataset. Both require elaborate preprocessing of the embedded documents for example.",No clear advantage of LLMs over simpler models,I'd love to connect with others who use LLMs embeddings and talk in more detail :),Looking to connect with others who use LLMs embeddings.,,,,,,,,,
85,Machine Learning Engineer,Machine Learning Engineer,,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,it isn't in focus on my leaders to use LLMs right now,Management Support,Two key questions I do myself on LLM in prod are: 1 - How is the best strategy to train or fine-tune a LLM ? 2 - How to manage infrastructure costs ?,"Training Strategy, Infrastructure Costs",not yet,No,,.,
86,CEO,CEO,,,1-10,No,,,,,,,,,,,,,,,,,,,,,,,"No current need, but also tooling","Lack of Use Case, Lack of Tooling","Reliability, safety, certainty, hallucinations, etc","Reliability, Safety, Certainty, Hallucinations",No,No,,,
87,Principal Cloud Developer,Cloud Developer,Principal,,50-500,Yes,"text resume, make ppts, text quizzes, text to flash cards, video resume etc,etc",,"Text Resume, PowerPoint Generation, Text Quizzes, Text to Flash Cards, Video Resume",-,,,,-,,"bad output, costs etc,etc","Bad output,Costs",Open AI API,-,,Fine tunning LLMS,Fine-Tuning,-,,-,,-,,,,,,,,,,
88,CPO,CPO,,,1-10,Yes,We help organizations transition Excel reports to Python,,Code Transcription,"Yes -- our product, Mito, is a spreadsheet that generates Python code as you edit it. We have integrated the chatgpt api into Mito so users can generate code using the LLM. Then, they can use the Mito spreadsheet to verify that the code it generated is correct.",Yes,ChatGPT,Code verification,We are not yet sure how large enterprises are going to adopt LLMs. Our large enterprise customers are currently not using the Mito AI feature because there is too much uncertainty.,"Entreprise Adoption, Uncertainty",,,Open AI API,Just the Mito spreadsheet,Mito Spreadsheet,Figuring out how to deploy LLMs for enterprise use,Deployment,We give users a spreadsheet interface to verify the output of the LLM. Spreadsheets are great for understanding changes to data!,User Interface,,,,,,,,,,,,,
89,Cloud MLOps Engineer,MLOps Engineer,,Cloud,10-50,Yes,Translate french text to english,,Translation,Yes we have used opus-mt model in containerised environment for translation,Yes,Opus-MT,Translation,It is pretty hard to work with this models as they need lot of resources to run which significantly increase the cost also,"Resource Requirements, Cost",Need of resources,Infrastructure Requirements,Other model provider API,Docker kubernetes aws resources,"Docker, Kubernetes, AWS",Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
90,CEO / Co-Founder,"CEO, Co-Founder",,,1-10,Yes,Writing SQL Queries from Natural Language.,,Code Generation,No,No,,,Getting it to write a query was relatively easy. Getting it to write a query that would actually be correct AND execute is much harder.,Accuracy,My concerns at this point are primarily focused around getting the LLM to generate an executable query in all cases.,Correctness,Open AI API,"Apache Drill, Python.","Apache Drill, Python",Fine tunning LLMS,Fine-Tuning,,,,,,,,,,,,,,,
91,Senior MLOps engineer,MLOps Engineer,Senior,,"1,000+",Yes,Adverse media about suppliers.,Risk Management,Adverse Media Analysis,"No, but have plans to do so! I will be involved in the feature store architecture.",No,,,The unpredictable nature of responses.,Unpredictability,That they give out results that are way off.,Correctness,Other model provider API,"Databricks, Azure","Databricks, Azure",Embeddings,Embeddings,Not well :D,,None yet,,,,,,,,,,,,
92,machine learning engineer,Machine Learning Engineer,,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Legal said not to,Legal restrictions,How do we keep costs down? How do we validate the outputs?,"Cost, Output Validation",nope,No,,,
93,CEO,CEO,,,1-10,Yes,Development of production tools for deployment/maintenance of LLMs and other models,"Software Deployment, Software Maintenance",,We have a platform to develop/run models in production called Statfish,Yes,Statfish,,Accuracy and hallucinations,"Accuracy, Hallucinations",Can't rely on answers 100% of the time,Reliability,"Open source model (GPT-J, etc)","Jupyter, kubernetes, haystack","Jupyter, Kubernetes, Haystack",Inferenece for LLMs,Inference,Working on that problem,TODO,,,,,,,,,,,,,
94,ML engineer,Machine Learning Engineer,,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,currently using classic ML and I plan to introduce LLM capabilities to my org,,"cost of training and inference, time, gpu, ....","Cost, Training, Inference, GPU",no,No,,,
95,Domain Chapter Lead - Data Science and AI,Domain Chapter Leader,Lead,Data Science and AI,"1,000+",Yes,Summarisation of customer calls,Customer Support,Text Summarization,nope,No,,,View of accuracy and quality of results,"Accuracy, Quality",Reliability,Reliability,Open AI API,Azure stack,Azure Stack,Embeddings,Embeddings,no framework yet,TODO,not much from our side yet,,How we manage quality of LLM outputs ?,How to manage quality of LLM outputs?,,,,,,,,,
96,Senior Machine Learning Engineer,Machine Learning Engineer,Senior,,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Lack of applicable business use cases and resources,"Lack of Use Case, Lack of Resources",How do you serve them?,Model Serving,Only for a developer,No,,,
97,VP of ML,Vice President,,Machine Learning,50-500,No,,,,,,,,,,,,,,,,,,,,,,,"Expensive, no ROI, complex, dangerous","Cost, Return of Investment, Complex, Dangerous",Is it reliable? How do we know it's reliable?,Reliability,Yes,Yes,,Expensive and the business use case was poorly defined. Just a shiny toy,"Cost, Business Requirements"
98,Technical Lead,Technical Leader,,,50-500,Yes,"POC, evaluation for healthtech",Healthcare,POC,,,,,supplement/support vs replace,"Support, Replacement",user risk,User risk,In house model,hf,Hugging Face,Fine tunning LLMS,Fine-Tuning,cross fingers,Hope,"not that i can share cheaply, ha",,"Growing LLM features iteratively & coherently vs Alphabet's ""put LLM in all the things!""",How to grow LLM features iteratively and coherently?,,,,,,,,,
99,Solutions engineer,Solutions Engineer,,,"500-1,000",Yes,Summarizes notes from meetings,,Meeting Note Summarization,no.,No,,,Not sure what's the standard,Standardization,The output can be unpredictable,Unpredictability,Open AI API,,,Inferenece for LLMs,Inference,Human evaluation,Human Evaluation,,,,,,,,,,,,,
100,Platform Engineer,Platform Engineer,,,50-500,No,,,,,,,,,,,,,,,,,,,,,,,No clear use case for our product,Lack of Use Case,,,No,No,,,
101,Senior MLOps,MLOps Engineer,Senior,,"1,000+",Yes,Chatbot,,Chatbot,integrate,,,,"rate limit,",Rate Limiting,"privacy, trustfulness, latency","Privacy,Trustfulness,Latency",Open AI API,vector databases,Vector Databases,Inferenece for LLMs,Inference,eval,Model Evaluation,,,,,,,,,,,,,
102,Data science manager,Manager,,Data Science,"1,000+",Yes,classification,,Text Classification,no custom tools,No,,,scaling :),Scalability,"great for batch, terrible for real time",Real Time Inference,"Open source model (GPT-J, etc)",azure ml suite,Azure ML,Embeddings,Embeddings,human verification of sample of inferences,Human Verification,we fine tune a bert sized model with our data and run the inference in batch. We experimented with quantization and distillation and its pretty impressive how much you can do with much smaller models.,Fine-tuned BERT model with quantization and distillation,,,,,,,,,,,
103,Data Scientist,Data Scientist,,,"500-1,000",No,,,,,,,,,,,,,,,,,,,,,,,LLMs and their hallucinations just are not good for our current use cases (healthcare industry),Hallucinations,,,"I have not, but I know many of the devs want to; there are some other reasonable use cases too.",No,,,
104,Principal Data Scientist,Data Scientist,Principal,,"1,000+",Yes,"Knowledge graph, transcription, topic modeling, embedding everything",,"Knowledge Graph, Text Transcription, Topic Modeling, Embedding","Yeah, but it's super secret until we try and sell it",Yes,,,Slow. They give bad answers when you set the confidence requirements too high,"Slowness, Reliability",Should we be paying for third party providers or train our own. Alpaca anyone?,Build vs buy,Open AI API,"Nvidia NeMO, Azure OpenAI","Nvidia NeMO, Azure OpenAI",Embeddings,Embeddings,Feedback button or manual review depending on use case,"User Feedbacks, Manual Review",Microsoft's call summarization tool can capture a surprising degree of detail while hilariously completely missing the main point of the meeting,Microsoft's call summarization tool captures detail but misses main point,Best practices to prevent leakage for client facing models that employ online learning?,What are the best practices to prevent leakage for client facing models with online learning?,,,,,,,,,
105,Manager Machine learning,Manager,,Machine Learning,"1,000+",No,,,,,,,,,,,,,,,,,,,,,,,Less expertise,Lack of Expertise,Large size models latency,Latency,,,,,
106,Data scientist,Data Scientist,,,1-10,Yes,User facing chat application in a narrow domain.,,Chatboot,In progress,Yes,,,,,,,Open AI API,,,Inferenece for LLMs,Inference,,,,,,,,,,,,,,,
107,Tech Lead,Tech Lead,,,"1,000+",Yes,,,,,,,,Compliance,,"Compliance, security and legal.","Compliance,Security,Legal",Open AI API,,,Fine tunning LLMS,Fine-Tuning,,,,,,,,,,,,,,,
108,Sr. Director AI/ML,Director,Senior,AI/ML,"1,000+",Yes,"ITSM, Sales Prospecting",IT Service Management,Sales Prospecting,chat bot,Yes,,Chatbot,scalabiltiy,Compliance,data privacy,Data privacy,"Open source model (GPT-J, etc)",kubeflow,Kubeflow,Fine tunning LLMS,Fine-Tuning,,,,,,,,,,,,,,,
109,BDM,Business Development Manager,,,"1,000+",Yes,"code development, summarisation",,"Code Development, Text Summarization","development environment, pipelining and deployment tooling",Yes,,,stack is immature; benchmarks are nonexistent; risk hard/impossible to gauge,Scalability,evaluating efficacy and ROI; understanding power needs/CO2 emissions,"Evaluation,ROI,Power Consumption,CO2 emissions",In house model,PyTorch + in-house tools,"PyTorch, In House",Inferenece for LLMs,Inference,user feedback,User Feedbacks,"extremely power-hungry, hard to scale; networking bandwidth is as important as memory when parallelising","LLMs are power-hungry and hard to scale, networking bandwidth is important",is anyone measuring LLM inference power consumption (and CO2 emissions)? what are the observed ranges of watts/inference of the various model sizes?,Is anyone measuring LLM inference power consumption and CO2 emissions? What are the observed ranges of watts/inference of the various model sizes?,,,,,,,,,
,,,,,,,,,,,,,,,"Immature Stack, Benchmarks, Risk Assessment",,,,,,,,,,,,,,,,,,,,,,'''

# %% [markdown]
# # IMPORTS

# %%
pip install -U kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
import pandas as pd
import plotly.io as pio
import plotly.express as px
from google.colab import files

from io import StringIO

# %% [markdown]
# # CONFIGS

# %%
# !mkdir images

# %%
pio.templates.default = 'plotly_white'

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # DATASETS

# %%
reviews = pd.read_csv(StringIO(REVIEWS), index_col=0)
print('Shape:', reviews.shape)
reviews.head()
# Out:
# Shape: (111, 37)
#     What is your position/title at your company?                      title  \
# 0.0                                          NaN                        NaN
# 1.0                               Data scientist             Data Scientist
# 2.0                                  ML Engineer  Machine Learning Engineer
# 3.0                                      Founder                    Founder
# 4.0                                        Owner                      Owner
#
#     position other How big is your organization? (number of employees)  \
# 0.0      NaN   NaN                                                 NaN
# 1.0      NaN   NaN                                              1,000+
# 2.0      NaN   NaN                                              50-500
# 3.0      NaN   NaN                                                1-10
# 4.0      NaN   NaN                                                1-10
#
#     Are you using LLM at in your organization?  \
# 0.0                                        NaN
# 1.0                                         No
# 2.0                                        Yes
# 3.0                                        Yes
# 4.0                                        Yes
#
#            What is your use case/use cases? fields  \
# 0.0                                     NaN    NaN
# 1.0                                     NaN    NaN
# 2.0                      Text summarisation    NaN
# 3.0  Data annotation; summarization; search    NaN
# 4.0    Content production and brainstorming    NaN
#
#                                            tasks  \
# 0.0                                          NaN
# 1.0                                          NaN
# 2.0                           Text Summarization
# 3.0  Data Annotation, Text Summarization, Search
# 4.0              Content Creation, Brainstorming
#
#     Have you integrated or built any internal tools to support LLMs in your org? If so what?  \
# 0.0                                                                                      NaN
# 1.0                                                                                      NaN
# 2.0                                                                                       No
# 3.0                                    https://chat.mantisnlp.com, internal annotation tools
# 4.0                                                                                  Not yet
#
#     integrated  solutions           purposes  \
# 0.0        NaN        NaN                NaN
# 1.0        NaN        NaN                NaN
# 2.0         No        NaN                NaN
# 3.0         No  MantisNLP  Internal Solution
# 4.0         No        NaN                NaN
#
#                        What are some of the main challenges you have encountered thus far when building with LLMs  \
# 0.0                                                                                                           NaN
# 1.0                                                                                                           NaN
# 2.0  Current infrastructure not designed for such massive models, having to implement workarounds for quick fixes
# 3.0                         out of date info, hallucinations, cost, difficulty in deploying on own infrastructure
# 4.0                                                                                                       not yet
#
#                                         challenges  \
# 0.0                                            NaN
# 1.0                                            NaN
# 2.0                     Infrastructure,Workarounds
# 3.0  Accuracy,Outdated Information,Cost,Deployment
# 4.0                                            NaN
#
#     What are your main concerns with using LLMs in production?  \
# 0.0                                                        NaN
# 1.0                                                        NaN
# 2.0                                                       Cost
# 3.0       they could serve nonsense or out of date information
# 4.0                                         cost of openai API
#
#                            concerns         how are you using LLMs?  \
# 0.0                             NaN                             NaN
# 1.0                             NaN                             NaN
# 2.0                            Cost  Open source model (GPT-J, etc)
# 3.0  Accuracy, Outdated Information                     Open AI API
# 4.0                            Cost                     Open AI API
#
#                         What tools are you using with LLMs?  \
# 0.0                                                     NaN
# 1.0                                                     NaN
# 2.0                                                  Seldon
# 3.0                                                     NaN
# 4.0  Looking at Pinecone, weaviate, langchain, hugging face
#
#                                            tools  \
# 0.0                                          NaN
# 1.0                                          NaN
# 2.0                                       Seldon
# 3.0                                          NaN
# 4.0  Pinecone, Weaviate, LangChain, Hugging Face
#
#     What areas are you most interested in learning more about?       topics  \
# 0.0                                                        NaN          NaN
# 1.0                                                        NaN          NaN
# 2.0                                        Inferenece for LLMs    Inference
# 3.0                                      Working with OSS LLMs  Open Source
# 4.0                                                 Embeddings   Embeddings
#
#                              How do you deal with reliability of output?  \
# 0.0                                                                  NaN
# 1.0                                                                  NaN
# 2.0                                                                  NaN
# 3.0  we provide links to the context from which answers have been drawn.
# 4.0                                                      temperature = 0
#
#               approaches  \
# 0.0                  NaN
# 1.0                  NaN
# 2.0                  NaN
# 3.0           References
# 4.0  Temperature Control
#
#     Any stories you have that are worth sharing about working with LLMs?  \
# 0.0                                                                  NaN
# 1.0                                                                  NaN
# 2.0                                                                  NaN
# 3.0                                                                  NaN
# 4.0                                                                  NaN
#
#     stories Any questions you have for the community about LLM in production?  \
# 0.0     NaN                                                               NaN
# 1.0     NaN                                                               NaN
# 2.0     NaN                                                               NaN
# 3.0     NaN                                                               NaN
# 4.0     NaN                                                               NaN
#
#     questions What is the main reason for not using LLMs in your org?  \
# 0.0       NaN                                                     NaN
# 1.0       NaN                             Production takes investment
# 2.0       NaN                                                     NaN
# 3.0       NaN                                                     NaN
# 4.0       NaN                                                     NaN
#
#              reasons  \
# 0.0              NaN
# 1.0  Production Cost
# 2.0              NaN
# 3.0              NaN
# 4.0              NaN
#
#     What are some key questions you face when it comes to using LLM in prod?  \
# 0.0                                                                      NaN
# 1.0                                             Cost to maintain the service
# 2.0                                                                      NaN
# 3.0                                                                      NaN
# 4.0                                                                      NaN
#
#             challenges.1  \
# 0.0                  NaN
# 1.0  Cost of Maintenance
# 2.0                  NaN
# 3.0                  NaN
# 4.0                  NaN
#
#     have you tried LLMs for different use cases in your org? tried cases  \
# 0.0                                                      NaN   NaN   NaN
# 1.0                                                      Yes   Yes   NaN
# 2.0                                                      NaN   NaN   NaN
# 3.0                                                      NaN   NaN   NaN
# 4.0                                                      NaN   NaN   NaN
#
#     If yes, why did it not work out?      problems
# 0.0                              NaN           NaN
# 1.0                     Date quality  Data Quality
# 2.0                              NaN           NaN
# 3.0                              NaN           NaN
# 4.0                              NaN           NaN

# %%
print('Review Columns:')
columns = list(reviews.columns)
for i, column in enumerate(columns):
    print(f'{i}. {column}')
# Out:
# Review Columns:
# 0. What is your position/title at your company?
# 1. title
# 2. position
# 3. other
# 4. How big is your organization? (number of employees)
# 5. Are you using LLM at in your organization?
# 6. What is your use case/use cases?
# 7. fields
# 8. tasks
# 9. Have you integrated or built any internal tools to support LLMs in your org? If so what?
# 10. integrated
# 11. solutions
# 12. purposes
# 13. What are some of the main challenges you have encountered thus far when building with LLMs
# 14. challenges
# 15. What are your main concerns with using LLMs in production?
# 16. concerns
# 17. how are you using LLMs?
# 18. What tools are you using with LLMs?
# 19. tools
# 20. What areas are you most interested in learning more about?
# 21. topics
# 22. How do you deal with reliability of output?
# 23. approaches
# 24. Any stories you have that are worth sharing about working with LLMs?
# 25. stories
# 26. Any questions you have for the community about LLM in production?
# 27. questions
# 28. What is the main reason for not using LLMs in your org?
# 29. reasons
# 30. What are some key questions you face when it comes to using LLM in prod?
# 31. challenges.1
# 32. have you tried LLMs for different use cases in your org?
# 33. tried
# 34. cases
# 35. If yes, why did it not work out?
# 36. problems

# %% [markdown]
# # FUNCTIONS

# %%
def count(df: pd.DataFrame, col: str, name: str) -> pd.DataFrame:
    """Count all values from a dataframe column."""
    data = df[col].value_counts().to_frame(name='Count')
    return data.reset_index(names=name) # give proper name

# %%
def count_all(df: pd.DataFrame, col: str, name: str) -> pd.DataFrame:
    """Count all values from a dataframe column."""
    data = df[col].str.split(',').explode().str.strip()
    counts = data.value_counts().to_frame(name='Count')
    return counts.reset_index(names=name) # give proper name

# %%
def barplot(df: pd.DataFrame, **kwargs):
    """Display a bar plot."""
    fig = px.bar(df, **kwargs)
    fig.update_layout(showlegend=False)
    return fig

# %%
def visualize(df: pd.DataFrame, col: str, name: str, path: str, norm: bool = True, **kwargs):
    """Visualize an entry for the survey."""
    if norm:
        data = count_all(df, col=col, name=name)
    else:
        data = count(df, col=col, name=name)
    fig = barplot(data, **kwargs)
    fig.write_image(path)
    return fig

# %% [markdown]
# # FIGURES

# %% [markdown]
# ## Question 0: What is your position/title at your company?

# %%
visualize(
    reviews,
    col='title', name='Job Title', path='images/job-title.png',
    y='Job Title', x='Count', color='Job Title', title='What is your job title at your company?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="50acf61f-0ffc-4abe-9224-a7d9f147465c" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50acf61f-0ffc-4abe-9224-a7d9f147465c")) {                    Plotly.newPlot(                        "50acf61f-0ffc-4abe-9224-a7d9f147465c",                        [{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Data Scientist","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Data Scientist","offsetgroup":"Data Scientist","orientation":"h","showlegend":true,"textposition":"auto","x":[17],"xaxis":"x","y":["Data Scientist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Machine Learning Engineer","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machine Learning Engineer","offsetgroup":"Machine Learning Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[16],"xaxis":"x","y":["Machine Learning Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Co-Founder","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Co-Founder","offsetgroup":"Co-Founder","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["Co-Founder"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"MLOps Engineer","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"MLOps Engineer","offsetgroup":"MLOps Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["MLOps Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Founder","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Founder","offsetgroup":"Founder","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["Founder"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"CTO","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"CTO","offsetgroup":"CTO","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["CTO"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"CEO","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"CEO","offsetgroup":"CEO","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["CEO"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Software Engineer","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Software Engineer","offsetgroup":"Software Engineer","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Software Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Manager","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Manager","offsetgroup":"Manager","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Manager"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Title=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Consultant","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Consultant","offsetgroup":"Consultant","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Consultant"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Ti ...

# %%
visualize(
    reviews,
    col='position', name='Job Position', path='images/job-position.png',
    y='Job Position', x='Count', color='Job Position', title='What is your job position at your company?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="088ef997-6407-4631-b535-dad603d55ce5" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("088ef997-6407-4631-b535-dad603d55ce5")) {                    Plotly.newPlot(                        "088ef997-6407-4631-b535-dad603d55ce5",                        [{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Senior","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Senior","offsetgroup":"Senior","orientation":"h","showlegend":true,"textposition":"auto","x":[18],"xaxis":"x","y":["Senior"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Head","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Head","offsetgroup":"Head","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["Head"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Lead","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Lead","offsetgroup":"Lead","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Lead"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Director","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Director","offsetgroup":"Director","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Director"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Principal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Principal","offsetgroup":"Principal","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Principal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Founding","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Founding","offsetgroup":"Founding","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Founding"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Junior","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Junior","offsetgroup":"Junior","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Junior"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Position=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Intern","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Intern","offsetgroup":"Intern","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Intern"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
visualize(
    reviews,
    col='other', name='Job Department', path='images/job-department.png',
    y='Job Department', x='Count', color='Job Department', title='What is your job department at your company?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ad7a5a56-3eae-471b-ad6c-0580a4346e0d" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad7a5a56-3eae-471b-ad6c-0580a4346e0d")) {                    Plotly.newPlot(                        "ad7a5a56-3eae-471b-ad6c-0580a4346e0d",                        [{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Machine Learning","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Machine Learning","offsetgroup":"Machine Learning","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Machine Learning"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Data Science","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Data Science","offsetgroup":"Data Science","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Data Science"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Product","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Product","offsetgroup":"Product","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Product"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Data Science and AI","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Data Science and AI","offsetgroup":"Data Science and AI","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Data Science and AI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cloud","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cloud","offsetgroup":"Cloud","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Cloud"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"DS & MLE","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"DS & MLE","offsetgroup":"DS & MLE","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["DS & MLE"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Agriculture","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Agriculture","offsetgroup":"Agriculture","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Agriculture"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"MLOps","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"MLOps","offsetgroup":"MLOps","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["MLOps"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Marketing","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Marketing","offsetgroup":"Marketing","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Marketing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job Department=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Data and ML","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Data and ML","offsetgroup":"Data and ML","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Data and ML"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","ho ...

# %% [markdown]
# ## Question 1: How big is your organization? (number of employees)

# %%
visualize(
    reviews, norm=False,
    col='How big is your organization? (number of employees)', name='Number of Employees', path='images/number-employees.png',
    y='Number of Employees', x='Count', color='Number of Employees', title='How big is your organization? (number of employees)', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fbc88c58-0531-4414-b875-0b6d5bee0b4c" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbc88c58-0531-4414-b875-0b6d5bee0b4c")) {                    Plotly.newPlot(                        "fbc88c58-0531-4414-b875-0b6d5bee0b4c",                        [{"alignmentgroup":"True","hovertemplate":"Number of Employees=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"1,000+","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1,000+","offsetgroup":"1,000+","orientation":"h","showlegend":true,"textposition":"auto","x":[33],"xaxis":"x","y":["1,000+"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Number of Employees=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"50-500","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"50-500","offsetgroup":"50-500","orientation":"h","showlegend":true,"textposition":"auto","x":[32],"xaxis":"x","y":["50-500"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Number of Employees=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"1-10","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1-10","offsetgroup":"1-10","orientation":"h","showlegend":true,"textposition":"auto","x":[28],"xaxis":"x","y":["1-10"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Number of Employees=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"10-50","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"10-50","offsetgroup":"10-50","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["10-50"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Number of Employees=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"500-1,000","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"500-1,000","offsetgroup":"500-1,000","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["500-1,000"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0. ...

# %% [markdown]
# ## Question 2: Are you using LLM at in your organization?

# %%
visualize(
    reviews, norm=False,
    col='Are you using LLM at in your organization?', name='Answer', path='images/using-llm.png',
    x='Answer', y='Count', color='Answer', title='Are you using LLM at in your organization?', height=500, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f28e93e7-da43-4e1c-9b6b-4a0f85f9259f" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f28e93e7-da43-4e1c-9b6b-4a0f85f9259f")) {                    Plotly.newPlot(                        "f28e93e7-da43-4e1c-9b6b-4a0f85f9259f",                        [{"alignmentgroup":"True","hovertemplate":"Answer=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["Yes"],"xaxis":"x","y":[67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Answer=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["No"],"xaxis":"x","y":[42],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %% [markdown]
# ## Question 3: What is your use case/use cases?

# %%
visualize(
    reviews,
    col='fields', name='Fields', path='images/cases-fields.png',
    y='Fields', x='Count', color='Fields', title='What is the fields associated with your use case/use cases?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5c1326a3-351b-4c58-addc-e79150956afa" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1326a3-351b-4c58-addc-e79150956afa")) {                    Plotly.newPlot(                        "5c1326a3-351b-4c58-addc-e79150956afa",                        [{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Marketing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Marketing","offsetgroup":"Marketing","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Marketing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Customer Support","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Customer Support","offsetgroup":"Customer Support","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Customer Support"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Healthcare","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Healthcare","offsetgroup":"Healthcare","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Healthcare"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Customer Service","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Customer Service","offsetgroup":"Customer Service","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Customer Service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"E-commerce","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"E-commerce","offsetgroup":"E-commerce","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["E-commerce"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Medical","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Medical","offsetgroup":"Medical","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Medical"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Sales","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sales","offsetgroup":"Sales","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Sales"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Software Maintenance","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Software Maintenance","offsetgroup":"Software Maintenance","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Software Maintenance"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Software Deployment","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Software Deployment","offsetgroup":"Software Deployment","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Software Deployment"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Fields=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Risk Management","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Risk Management","offsetgroup":"Risk Management","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Risk Management"],"yaxis":"y","type":"bar"},{"alignmentg ...

# %%
visualize(
    reviews,
    col='tasks', name='Tasks', path='images/cases-tasks.png',
    y='Tasks', x='Count', color='Tasks', title='What is the NLP tasks associated with your use case/use cases?', height=1200, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c992296e-83aa-4a77-a76d-a62634cb2b8f" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c992296e-83aa-4a77-a76d-a62634cb2b8f")) {                    Plotly.newPlot(                        "c992296e-83aa-4a77-a76d-a62634cb2b8f",                        [{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Text Generation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Text Generation","offsetgroup":"Text Generation","orientation":"h","showlegend":true,"textposition":"auto","x":[9],"xaxis":"x","y":["Text Generation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Text Summarization","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Text Summarization","offsetgroup":"Text Summarization","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["Text Summarization"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Chatbot","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Chatbot","offsetgroup":"Chatbot","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["Chatbot"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Text Classification","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Text Classification","offsetgroup":"Text Classification","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["Text Classification"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Search","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Search","offsetgroup":"Search","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Search"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Information Retrieval","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Information Retrieval","offsetgroup":"Information Retrieval","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Information Retrieval"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Code Generation","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Code Generation","offsetgroup":"Code Generation","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Code Generation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Question Answering","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Question Answering","offsetgroup":"Question Answering","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Question Answering"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Topic Modeling","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Topic Modeling","offsetgroup":"Topic Modeling","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Topic Modeling"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tasks=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Content Creation","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Content Creation","offsetgroup":"Content Creation","orientation":"h","showlegend":true,"textposition":"auto","x": ...

# %% [markdown]
# ## Question 4: Have you integrated or built any internal tools to support LLMs in your org? If so what?

# %%
visualize(
    reviews,
    col='integrated', name='Answer', path='images/integration-answer.png',
    x='Answer', y='Count', color='Answer', title='Have you integrated or built any internal tools to support LLMs in your org?', height=500, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5d7ef572-86d3-4058-8f68-b974918b0cde" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d7ef572-86d3-4058-8f68-b974918b0cde")) {                    Plotly.newPlot(                        "5d7ef572-86d3-4058-8f68-b974918b0cde",                        [{"alignmentgroup":"True","hovertemplate":"Answer=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["No"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Answer=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["Yes"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %%
visualize(
    reviews,
    col='solutions', name='Solutions', path='images/integration-solutions.png',
    y='Solutions', x='Count', color='Solutions', title='Which solutions have you integrated to support LLMs in your org?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="58c44f34-916b-434c-b70a-f1df5d45b4e8" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58c44f34-916b-434c-b70a-f1df5d45b4e8")) {                    Plotly.newPlot(                        "58c44f34-916b-434c-b70a-f1df5d45b4e8",                        [{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Langchain","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Langchain","offsetgroup":"Langchain","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Langchain"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"ChatGPT","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ChatGPT","offsetgroup":"ChatGPT","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["ChatGPT"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"OpenAI","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"OpenAI","offsetgroup":"OpenAI","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["OpenAI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"PromptLayer","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"PromptLayer","offsetgroup":"PromptLayer","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["PromptLayer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Opus-MT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Opus-MT","offsetgroup":"Opus-MT","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Opus-MT"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Kubernetes","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Haystack","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Haystack","offsetgroup":"Haystack","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Haystack"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"RASA","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"RASA","offsetgroup":"RASA","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["RASA"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"HuggingFace","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"HuggingFace","offsetgroup":"HuggingFace","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["HuggingFace"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Weaviate","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Weaviate","offsetgroup":"Weaviate","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Weaviate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Solutions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"MantisNLP","marker":{"color":"#636efa","pattern":{"shape":""}}," ...

# %%
visualize(
    reviews,
    col='purposes', name='Purposes', path='images/integration-purposes.png',
    y='Purposes', x='Count', color='Purposes', title='For which purposes have you integrated LLMs in your org?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3a41141a-45fd-430f-9434-eaf290a682fc" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a41141a-45fd-430f-9434-eaf290a682fc")) {                    Plotly.newPlot(                        "3a41141a-45fd-430f-9434-eaf290a682fc",                        [{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Chatbot","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Chatbot","offsetgroup":"Chatbot","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Chatbot"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Question Answering","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Question Answering","offsetgroup":"Question Answering","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Question Answering"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Internal Solution","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Internal Solution","offsetgroup":"Internal Solution","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Internal Solution"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Internal tools","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Internal tools","offsetgroup":"Internal tools","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Internal tools"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Text Classification","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Text Classification","offsetgroup":"Text Classification","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Text Classification"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Prompt testing","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Prompt testing","offsetgroup":"Prompt testing","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Prompt testing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Prompt Generation","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Prompt Generation","offsetgroup":"Prompt Generation","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Prompt Generation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Embeddings","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Embeddings","offsetgroup":"Embeddings","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Embeddings"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Output validation","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Output validation","offsetgroup":"Output validation","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Output validation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Purposes=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"POC","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"POC","offsetgroup":"POC","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis ...

# %% [markdown]
# ## Question 5: What are some of the main challenges you have encountered thus far when building with LLMs

# %%
visualize(
    reviews,
    col='challenges', name='Challenges', path='images/build-challenges.png',
    y='Challenges', x='Count', color='Challenges', title='What are some of the main challenges you have encountered thus far when building with LLMs?', height=1200, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8c3cb291-4e4f-480c-a1e9-e9d30195bbd8" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c3cb291-4e4f-480c-a1e9-e9d30195bbd8")) {                    Plotly.newPlot(                        "8c3cb291-4e4f-480c-a1e9-e9d30195bbd8",                        [{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Accuracy","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Accuracy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cost","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cost","offsetgroup":"Cost","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Cost"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Debugging","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Debugging","offsetgroup":"Debugging","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Debugging"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Deployment","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Deployment","offsetgroup":"Deployment","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Deployment"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Explainability","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Explainability","offsetgroup":"Explainability","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Explainability"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Latency","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Latency","offsetgroup":"Latency","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Latency"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Data labeling","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Data labeling","offsetgroup":"Data labeling","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Data labeling"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Testing","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Testing","offsetgroup":"Testing","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Testing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Performance","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Performance","offsetgroup":"Performance","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Performance"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Scalability","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Scalability","offsetgroup":"Scalability","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Scalability"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":" ...

# %% [markdown]
# ## Question 6: What are your main concerns with using LLMs in production?

# %%
visualize(
    reviews,
    col='concerns', name='Concerns', path='images/production-concerns.png',
    y='Concerns', x='Count', color='Concerns', title='What are your main concerns with using LLMs in production?', height=1200, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ceda9b31-9d2e-47a1-b47d-d12615077776" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ceda9b31-9d2e-47a1-b47d-d12615077776")) {                    Plotly.newPlot(                        "ceda9b31-9d2e-47a1-b47d-d12615077776",                        [{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cost","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cost","offsetgroup":"Cost","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["Cost"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Hallucinations","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Hallucinations","offsetgroup":"Hallucinations","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["Hallucinations"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Reliability","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Reliability","offsetgroup":"Reliability","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["Reliability"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Latency","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Latency","offsetgroup":"Latency","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["Latency"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Costs","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Costs","offsetgroup":"Costs","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Costs"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Security","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Security","offsetgroup":"Security","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Security"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Truthfulness","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Truthfulness","offsetgroup":"Truthfulness","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Truthfulness"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Scalability","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Scalability","offsetgroup":"Scalability","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Scalability"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Consistency","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Consistency","offsetgroup":"Consistency","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Consistency"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Accuracy","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Accuracy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Concerns=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Explainability","marker":{"color": ...

# %% [markdown]
# ## Question 7: How are you using LLMs?

# %%
visualize(
    reviews, norm=False,
    col='how are you using LLMs?', name='Answer', path='images/using-answer.png',
    y='Answer', x='Count', color='Answer', title='How are you using LLMs?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="27c7c988-8e52-4403-95ad-863064255006" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27c7c988-8e52-4403-95ad-863064255006")) {                    Plotly.newPlot(                        "27c7c988-8e52-4403-95ad-863064255006",                        [{"alignmentgroup":"True","hovertemplate":"Answer=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Open AI API","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Open AI API","offsetgroup":"Open AI API","orientation":"h","showlegend":true,"textposition":"auto","x":[33],"xaxis":"x","y":["Open AI API"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Answer=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Open source model (GPT-J, etc)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Open source model (GPT-J, etc)","offsetgroup":"Open source model (GPT-J, etc)","orientation":"h","showlegend":true,"textposition":"auto","x":[18],"xaxis":"x","y":["Open source model (GPT-J, etc)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Answer=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"In house model","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"In house model","offsetgroup":"In house model","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["In house model"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Answer=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Other model provider API","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Other model provider API","offsetgroup":"Other model provider API","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["Other model provider API"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d857 ...

# %% [markdown]
# ## Question 8: What tools are you using with LLMs?

# %%
visualize(
    reviews,
    col='tools', name='Tools', path='images/tools-llm.png',
    y='Tools', x='Count', color='Tools', title='What tools are you using with LLMs?', height=1200, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6f9e4a0e-d07e-4bc3-a410-8834299bf242" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f9e4a0e-d07e-4bc3-a410-8834299bf242")) {                    Plotly.newPlot(                        "6f9e4a0e-d07e-4bc3-a410-8834299bf242",                        [{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"LangChain","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LangChain","offsetgroup":"LangChain","orientation":"h","showlegend":true,"textposition":"auto","x":[10],"xaxis":"x","y":["LangChain"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Hugging Face","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Hugging Face","offsetgroup":"Hugging Face","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["Hugging Face"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Kubernetes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Kubernetes","offsetgroup":"Kubernetes","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Kubernetes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"PyTorch","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"PyTorch","offsetgroup":"PyTorch","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["PyTorch"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"In House","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"In House","offsetgroup":"In House","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["In House"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"OpenAI","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"OpenAI","offsetgroup":"OpenAI","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["OpenAI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"AWS","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"AWS","offsetgroup":"AWS","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["AWS"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Pinecone","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Pinecone","offsetgroup":"Pinecone","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Pinecone"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Haystack","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Haystack","offsetgroup":"Haystack","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Haystack"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Python","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Python","offsetgroup":"Python","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Python"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Tools=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"TensorFlow","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TensorFlow","offsetgroup":"TensorFlow","orientatio ...

# %% [markdown]
# ## Question 9: What areas are you most interested in learning more about?

# %%
visualize(
    reviews,
    col='topics', name='Topics', path='images/interest-topics.png',
    y='Topics', x='Count', color='Topics', title='What areas are you most interested in learning more about?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f0b20562-0cf8-4370-8ba1-67656e79c894" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0b20562-0cf8-4370-8ba1-67656e79c894")) {                    Plotly.newPlot(                        "f0b20562-0cf8-4370-8ba1-67656e79c894",                        [{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Fine-Tuning","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fine-Tuning","offsetgroup":"Fine-Tuning","orientation":"h","showlegend":true,"textposition":"auto","x":[21],"xaxis":"x","y":["Fine-Tuning"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Inference","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Inference","offsetgroup":"Inference","orientation":"h","showlegend":true,"textposition":"auto","x":[17],"xaxis":"x","y":["Inference"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Embeddings","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Embeddings","offsetgroup":"Embeddings","orientation":"h","showlegend":true,"textposition":"auto","x":[16],"xaxis":"x","y":["Embeddings"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Open Source","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Open Source","offsetgroup":"Open Source","orientation":"h","showlegend":true,"textposition":"auto","x":[10],"xaxis":"x","y":["Open Source"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"React Pattern","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"React Pattern","offsetgroup":"React Pattern","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["React Pattern"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Edge Cases","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Edge Cases","offsetgroup":"Edge Cases","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Edge Cases"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Prompt Engineering","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Prompt Engineering","offsetgroup":"Prompt Engineering","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Prompt Engineering"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Calibration","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Calibration","offsetgroup":"Calibration","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Calibration"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Testing","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Testing","offsetgroup":"Testing","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Testing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Topics=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Deployment","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Deployment","offsetgroup":"Deployment","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Deployment"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type": ...

# %% [markdown]
# ## Question 10: How do you deal with reliability of output?

# %%
visualize(
    reviews,
    col='approaches', name='Approaches', path='images/reliability-approaches.png',
    y='Approaches', x='Count', color='Approaches', title='How do you deal with reliability of output?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="23e6cbde-d6fd-4215-970f-79f9b29d6f93" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23e6cbde-d6fd-4215-970f-79f9b29d6f93")) {                    Plotly.newPlot(                        "23e6cbde-d6fd-4215-970f-79f9b29d6f93",                        [{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Nothing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Nothing","offsetgroup":"Nothing","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Nothing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Manual Review","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Manual Review","offsetgroup":"Manual Review","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Manual Review"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Model Evaluation","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Model Evaluation","offsetgroup":"Model Evaluation","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Model Evaluation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"User Feedbacks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"User Feedbacks","offsetgroup":"User Feedbacks","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["User Feedbacks"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"User Feedback","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"User Feedback","offsetgroup":"User Feedback","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["User Feedback"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Human-in-the-Loop (HITL)","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Human-in-the-Loop (HITL)","offsetgroup":"Human-in-the-Loop (HITL)","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Human-in-the-Loop (HITL)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"TODO","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"TODO","offsetgroup":"TODO","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["TODO"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Extensive Testing","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Extensive Testing","offsetgroup":"Extensive Testing","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Extensive Testing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Error Handling","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Error Handling","offsetgroup":"Error Handling","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Error Handling"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Approaches=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Validation Set","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Validation Set","offsetgroup":"Validation Set","orientation":"h","showlegend":true,"textposition":"auto","x":[ ...

# %% [markdown]
# ## Question 11: Any stories you have that are worth sharing about working with LLMs?

# %%
visualize(
    reviews,
    col='stories', name='Stories', path='images/share-stories.png',
    y='Stories', x='Count', color='Stories', title='Any stories you have that are worth sharing about working with LLMs?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c080a6b9-192b-4d72-99b2-dae3ce8d7506" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c080a6b9-192b-4d72-99b2-dae3ce8d7506")) {                    Plotly.newPlot(                        "c080a6b9-192b-4d72-99b2-dae3ce8d7506",                        [{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Production issues with LLMs","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Production issues with LLMs","offsetgroup":"Production issues with LLMs","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Production issues with LLMs"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"LLM hallucination without actual usage","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LLM hallucination without actual usage","offsetgroup":"LLM hallucination without actual usage","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["LLM hallucination without actual usage"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"LLMs are power-hungry and hard to scale","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LLMs are power-hungry and hard to scale","offsetgroup":"LLMs are power-hungry and hard to scale","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["LLMs are power-hungry and hard to scale"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Microsoft's call summarization tool captures detail but misses main point","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Microsoft's call summarization tool captures detail but misses main point","offsetgroup":"Microsoft's call summarization tool captures detail but misses main point","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Microsoft's call summarization tool captures detail but misses main point"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Fine-tuned BERT model with quantization and distillation","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Fine-tuned BERT model with quantization and distillation","offsetgroup":"Fine-tuned BERT model with quantization and distillation","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Fine-tuned BERT model with quantization and distillation"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"No clear advantage of LLMs over simpler models","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"No clear advantage of LLMs over simpler models","offsetgroup":"No clear advantage of LLMs over simpler models","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["No clear advantage of LLMs over simpler models"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Scalability is a real challenge","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Scalability is a real challenge","offsetgroup":"Scalability is a real challenge","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Scalability is a real challenge"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stories=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Development time is under-estimated","marker":{"colo ...

# %% [markdown]
# ## Question 12: Any questions you have for the community about LLM in production?

# %%
visualize(
    reviews,
    col='questions', name='Questions', path='images/community-questions.png',
    y='Questions', x='Count', color='Questions', title='Any questions you have for the community about LLM in production?', height=800, width=1600,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9b9c6433-f01c-45ee-8c15-f153de69a3e3" class="plotly-graph-div" style="height:800px; width:1600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b9c6433-f01c-45ee-8c15-f153de69a3e3")) {                    Plotly.newPlot(                        "9b9c6433-f01c-45ee-8c15-f153de69a3e3",                        [{"alignmentgroup":"True","hovertemplate":"Questions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"How do other people monitor LLMs and deal with GDPR limitations?","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"How do other people monitor LLMs and deal with GDPR limitations?","offsetgroup":"How do other people monitor LLMs and deal with GDPR limitations?","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["How do other people monitor LLMs and deal with GDPR limitations?"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Questions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Where is the line drawn between training models locally and using LLMs? Can LLMs be used to bootstrap training data for smaller models?","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Where is the line drawn between training models locally and using LLMs? Can LLMs be used to bootstrap training data for smaller models?","offsetgroup":"Where is the line drawn between training models locally and using LLMs? Can LLMs be used to bootstrap training data for smaller models?","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Where is the line drawn between training models locally and using LLMs? Can LLMs be used to bootstrap training data for smaller models?"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Questions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"What are the best practices to prevent leakage for client facing models with online learning?","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"What are the best practices to prevent leakage for client facing models with online learning?","offsetgroup":"What are the best practices to prevent leakage for client facing models with online learning?","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["What are the best practices to prevent leakage for client facing models with online learning?"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Questions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"How to grow LLM features iteratively and coherently?","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"How to grow LLM features iteratively and coherently?","offsetgroup":"How to grow LLM features iteratively and coherently?","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["How to grow LLM features iteratively and coherently?"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Questions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"How to manage quality of LLM outputs?","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"How to manage quality of LLM outputs?","offsetgroup":"How to manage quality of LLM outputs?","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["How to manage quality of LLM outputs?"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Questions=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Looking to connect with others who use LLMs embeddings.","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Looking to connect with others who use LLMs embeddings.","offsetgroup":"Looking to connect with others who use LLMs embeddings.","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Looking to con ...

# %% [markdown]
# ## Question 13: What is the main reason for not using LLMs in your org?

# %%
visualize(
    reviews,
    col='reasons', name='Reasons', path='images/blocking-reasons.png',
    y='Reasons', x='Count', color='Reasons', title='What is the main reason for not using LLMs in your org?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="41caa5f2-3204-478d-8b48-b5c1d8618c8d" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41caa5f2-3204-478d-8b48-b5c1d8618c8d")) {                    Plotly.newPlot(                        "41caa5f2-3204-478d-8b48-b5c1d8618c8d",                        [{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Lack of Use Case","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Lack of Use Case","offsetgroup":"Lack of Use Case","orientation":"h","showlegend":true,"textposition":"auto","x":[13],"xaxis":"x","y":["Lack of Use Case"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cost","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cost","offsetgroup":"Cost","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["Cost"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Not Applicable","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Not Applicable","offsetgroup":"Not Applicable","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Not Applicable"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Return of Investment","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Return of Investment","offsetgroup":"Return of Investment","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Return of Investment"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Hallucinations","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Hallucinations","offsetgroup":"Hallucinations","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Hallucinations"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Production Cost","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Production Cost","offsetgroup":"Production Cost","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Production Cost"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Lack of Maturity","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Lack of Maturity","offsetgroup":"Lack of Maturity","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Lack of Maturity"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Domain Specific Language","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Domain Specific Language","offsetgroup":"Domain Specific Language","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Domain Specific Language"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Compute Intensive","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Compute Intensive","offsetgroup":"Compute Intensive","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Compute Intensive"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Reasons=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Business Risks","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Business Risks","offsetgroup":"Business Risks","orientation":"h","s ...

# %% [markdown]
# ## Question 14: What are some key questions you face when it comes to using LLM in prod?

# %%
visualize(
    reviews,
    col='challenges.1', name='Challenges', path='images/prod-questions.png',
    y='Challenges', x='Count', color='Challenges', title='What are some key questions you face when it comes to using LLM in prod?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7faebac9-2c0b-4725-82d3-c6a320a146af" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7faebac9-2c0b-4725-82d3-c6a320a146af")) {                    Plotly.newPlot(                        "7faebac9-2c0b-4725-82d3-c6a320a146af",                        [{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cost","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cost","offsetgroup":"Cost","orientation":"h","showlegend":true,"textposition":"auto","x":[10],"xaxis":"x","y":["Cost"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Reliability","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Reliability","offsetgroup":"Reliability","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x","y":["Reliability"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Hallucinations","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Hallucinations","offsetgroup":"Hallucinations","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Hallucinations"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Fine-tuning","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Fine-tuning","offsetgroup":"Fine-tuning","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Fine-tuning"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Latency","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Latency","offsetgroup":"Latency","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Latency"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Accuracy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Accuracy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Domain Specific Knowledge","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Domain Specific Knowledge","offsetgroup":"Domain Specific Knowledge","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Domain Specific Knowledge"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cost of Maintenance","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Cost of Maintenance","offsetgroup":"Cost of Maintenance","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Cost of Maintenance"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"ROI","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"ROI","offsetgroup":"ROI","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["ROI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Challenges=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Output Validation","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Output Validation","offsetgroup":"Output Validation","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Output Validation"],"yaxis":"y","type":"bar"},{"a ...

# %% [markdown]
# ## Question 15: Have you tried LLMs for different use cases in your org?

# %%
visualize(
    reviews,
    col='tried', name='Answer', path='images/try-answer.png',
    x='Answer', y='Count', color='Answer', title='Have you tried LLMs for different use cases in your org?', height=600, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dc670aa5-2c5f-4e5c-9477-33dbac41ebc0" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc670aa5-2c5f-4e5c-9477-33dbac41ebc0")) {                    Plotly.newPlot(                        "dc670aa5-2c5f-4e5c-9477-33dbac41ebc0",                        [{"alignmentgroup":"True","hovertemplate":"Answer=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["No"],"xaxis":"x","y":[19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Answer=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["Yes"],"xaxis":"x","y":[12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %%
visualize(
    reviews,
    col='cases', name='Use Cases', path='images/try-cases.png',
    y='Use Cases', x='Count', color='Use Cases', title='On which use case have you tried LLMs in your org?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9030aa20-305f-4634-9001-b0c4f7a5a782" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9030aa20-305f-4634-9001-b0c4f7a5a782")) {                    Plotly.newPlot(                        "9030aa20-305f-4634-9001-b0c4f7a5a782",                        [{"alignmentgroup":"True","hovertemplate":"Use Cases=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Plant Diseases","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Plant Diseases","offsetgroup":"Plant Diseases","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Plant Diseases"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Use Cases=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Classification","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Classification","offsetgroup":"Classification","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Classification"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Use Cases=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Customer and Colleague Facing Applications","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Customer and Colleague Facing Applications","offsetgroup":"Customer and Colleague Facing Applications","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Customer and Colleague Facing Applications"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Use Cases=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Recommendation System","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Recommendation System","offsetgroup":"Recommendation System","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Recommendation System"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Use Cases=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Clustering","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Clustering","offsetgroup":"Clustering","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Clustering"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...

# %% [markdown]
# ## Question 16: If yes, why did it not work out?

# %%
visualize(
    reviews,
    col='problems', name='Problems', path='images/try-problems.png',
    y='Problems', x='Count', color='Problems', title='If yes, why did it not work out?', height=800, width=1200,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9f64644f-1d0e-4a60-8861-0981e05b1f7b" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f64644f-1d0e-4a60-8861-0981e05b1f7b")) {                    Plotly.newPlot(                        "9f64644f-1d0e-4a60-8861-0981e05b1f7b",                        [{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Veracity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Veracity","offsetgroup":"Veracity","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Veracity"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Cost","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cost","offsetgroup":"Cost","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Cost"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"None","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["None"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Data Quality","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Data Quality","offsetgroup":"Data Quality","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Data Quality"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Reliability","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Reliability","offsetgroup":"Reliability","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Reliability"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"ROI","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ROI","offsetgroup":"ROI","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["ROI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Business Risks","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Business Risks","offsetgroup":"Business Risks","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Business Risks"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Efficiency","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Efficiency","offsetgroup":"Efficiency","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Efficiency"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Fine Tuning","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Fine Tuning","offsetgroup":"Fine Tuning","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Fine Tuning"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"LLMOps","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"LLMOps","offsetgroup":"LLMOps","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["LLMOps"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Problems=%{y}<br>Count=%{x}<extra></extra>","legendgroup":"Model Size","marker":{"color":"#636efa","pattern":{"shape":""}},"na ...

# %% [markdown]
# # EXPORTS

# %%
# !zip images.zip images/*
# Out:
#   adding: images/blocking-reasons.png (deflated 14%)
#   adding: images/build-challenges.png (deflated 16%)
#   adding: images/cases-fields.png (deflated 26%)
#   adding: images/cases-tasks.png (deflated 19%)
#   adding: images/community-questions.png (deflated 13%)
#   adding: images/integration-answer.png (deflated 44%)
#   adding: images/integration-purposes.png (deflated 31%)
#   adding: images/integration-solutions.png (deflated 29%)
#   adding: images/interest-topics.png (deflated 35%)
#   adding: images/job-department.png (deflated 25%)
#   adding: images/job-position.png (deflated 51%)
#   adding: images/job-title.png (deflated 19%)
#   adding: images/number-employees.png (deflated 42%)
#   adding: images/prod-questions.png (deflated 16%)
#   adding: images/production-concerns.png (deflated 18%)
#   adding: images/reliability-approaches.png (deflated 12%)
#   adding: images/share-stories.png (deflated 16%)
#   adding: images/tools-llm.png (deflated 20%)
#   adding: images/try-answer.png (deflated 51%)
#   adding: images/try-cases.png (deflated 41%)
#   adding: images/try-problems.png (deflated 28%)
#   adding: images/using-answer.png (deflated 47%)
#   adding: images/using-llm.png (deflated 46%)

# %%
# files.download('images.zip')
